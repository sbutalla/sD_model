# %%
import numpy as np
import pandas as pd
import re
import itertools

# %%
from glob import glob
def get_file_list(base_dir, file_ext = None, recglob = False):
    '''
    S. D. Butalla
    2022/08/17 - v0
    
    Generic function that retrieves a list of files in 
    a specified directory. An option for recursive
    globbing for all subdirectories given a base 
    directory is also available.
    
    Dependencies:
    
    glob
    
    Positional arguments:
    base_dir          : (string) The base directory to
                        retrieve the files from.
    Optional arguments:
    file_ext          : (string) File extension. If not
                        None, all contents of directory
                        will be returned (including    
                        directories).
    recglob           : (bool) Enable recursive 
                        globbing.
    
    Output:
    total_file_list   : (list; string) List of strings
                        of complete file paths
    file_names        : (list; string) List of strings
                        of file names (including those 
                        in subdirectories!).
    '''
    if file_ext is not None:
        if file_ext[0] != ".":
            file_ext = "." + file_ext
    else:
        file_ext = ""

    if recglob:
        total_file_list = glob(f'{base_dir}/*/*%s' % file_ext)
    else:
        total_file_list = glob(f'{base_dir}/*%s' % file_ext)
    
    file_names = [file.split("/")[-1] for file in total_file_list]
    return total_file_list, file_names

# %%
base_dirs = ["2017_CutFlow_tables/", "2018_CutFlow_tables/"]
base_dir  = base_dirs[1]
total_file_list, file_names = get_file_list(base_dir, ".tex")

# %%
total_file_list
# Out:
# ['2018_CutFlow_tables/MZD_100_MSD_50.tex',
#  '2018_CutFlow_tables/MZD_100_SD_10.tex',
#  '2018_CutFlow_tables/MZD_100_SD_15.tex',
#  '2018_CutFlow_tables/MZD_100_SD_20.tex',
#  '2018_CutFlow_tables/MZD_100_SD_25.tex',
#  '2018_CutFlow_tables/MZD_100_SD_30.tex',
#  '2018_CutFlow_tables/MZD_100_SD_35.tex',
#  '2018_CutFlow_tables/MZD_100_SD_40.tex',
#  '2018_CutFlow_tables/MZD_100_SD_45.tex',
#  '2018_CutFlow_tables/MZD_100_SD_5.tex',
#  '2018_CutFlow_tables/MZD_110_MSD_10.tex',
#  '2018_CutFlow_tables/MZD_110_MSD_15.tex',
#  '2018_CutFlow_tables/MZD_110_MSD_20.tex',
#  '2018_CutFlow_tables/MZD_110_MSD_25.tex',
#  '2018_CutFlow_tables/MZD_110_MSD_30.tex',
#  '2018_CutFlow_tables/MZD_110_MSD_35.tex',
#  '2018_CutFlow_tables/MZD_110_MSD_40.tex',
#  '2018_CutFlow_tables/MZD_110_MSD_45.tex',
#  '2018_CutFlow_tables/MZD_110_MSD_5.tex',
#  '2018_CutFlow_tables/MZD_110_MSD_50.tex',
#  '2018_CutFlow_tables/MZD_110_MSD_55.tex',
#  '2018_CutFlow_tables/MZD_125_MSD_10.tex',
#  '2018_CutFlow_tables/MZD_125_MSD_20.tex',
#  '2018_CutFlow_tables/MZD_125_MSD_40.tex',
#  '2018_CutFlow_tables/MZD_125_SD_15.tex',
#  '2018_CutFlow_tables/MZD_125_SD_25.tex',
#  '2018_CutFlow_tables/MZD_125_SD_30.tex',
#  '2018_CutFlow_tables/MZD_125_SD_35.tex',
#  '2018_CutFlow_tables/MZD_125_SD_45.tex',
#  '2018_CutFlow_tables/MZD_125_SD_5.tex',
#  '2018_CutFlow_tables/MZD_125_SD_50.tex',
#  '2018_CutFlow_tables/MZD_125_SD_55.tex',
#  '2018_CutFlow_tables/MZD_125_SD_60.tex',
#  '2018_CutFlow_tables/MZD_130_MSD_10.tex',
#  '2018_CutFlow_tables/MZD_160_MSD_10.tex',
#  '2018_CutFlow_tables/MZD_160_MSD_15.tex',
#  '2018_CutFlow_tables/MZD_160_MSD_20.tex',
#  '2018_CutFlow_tables/MZD_160_MSD_25.tex',
#  '2018_CutFlow_tables/MZD_160_MSD_30.tex',
#  '2018_CutFlow_tables/MZD_160_MSD_35.tex',
#  '2018_CutFlow_tables/MZD_160_MSD_40.tex',
#  '2018_CutFlow_tables/MZD_160_MSD_45.tex',
#  '2018_CutFlow_tables/MZD_160_MSD_5.tex',
#  '2018_CutFlow_tables/MZD_160_MSD_50.tex',
#  '2018_CutFlow_tables/MZD_160_MSD_55.tex',
#  '2018_CutFlow_tables/MZD_160_MSD_60.tex',
#  '2018_CutFlow_tables/MZD_160_MSD_70.tex',
#  '2018_CutFlow_tables/MZD_160_MSD_80.tex',
#  '2018_CutFlow_tables/MZD_200_MSD_15.tex',
#  '2018_CutFlow_tables/MZD_200_MSD_25.tex',
#  '2018_CutFlow_tables/MZD_200_MSD_35.tex',
#  '2018_CutFlow_tables/MZD_200_MSD_45.tex',
#  '2018_CutFlow_tables/MZD_200_MSD_55.tex',
#  '2018_CutFlow_tables/MZD_200_SD_10.tex',
#  '2018_CutFlow_tables/MZD_200_SD_100.tex',
#  '2018_CutFlow_tables/MZD_200_SD_20.tex',
#  '2018_CutFlow_tables/MZD_200_SD_30.tex',
#  '2018_CutFlow_tables/MZD_200_SD_40.tex',
#  '2018_CutFlow_tables/MZD_200_SD_5.tex',
#  '2018_CutFlow_tables/MZD_200_SD_50.tex',
#  '2018_CutFlow_tables/MZD_200_SD_60.tex',
#  '2018_CutFlow_tables/MZD_200_SD_80.tex',
#  '2018_CutFlow_tables/MZD_80_MSD_35.tex',
#  '2018_CutFlow_tables/MZD_80_SD_10.tex',
#  '2018_CutFlow_tables/MZD_80_SD_15.tex',
#  '2018_CutFlow_tables/MZD_80_SD_20.tex',
#  '2018_CutFlow_tables/MZD_80_SD_25.tex',
#  '2018_CutFlow_tables/MZD_80_SD_30.tex',
#  '2018_CutFlow_tables/MZD_80_SD_35.tex',
#  '2018_CutFlow_tables/MZD_80_SD_5.tex',
#  '2018_CutFlow_tables/MZD_85_MSD_10.tex',
#  '2018_CutFlow_tables/MZD_85_MSD_15.tex',
#  '2018_CutFlow_tables/MZD_85_MSD_20.tex',
#  '2018_CutFlow_tables/MZD_85_MSD_25.tex',
#  '2018_CutFlow_tables/MZD_85_MSD_30.tex',
#  '2018_CutFlow_tables/MZD_85_MSD_35.tex',
#  '2018_CutFlow_tables/MZD_85_MSD_40.tex',
#  '2018_CutFlow_tables/MZD_85_MSD_5.tex',
#  '2018_CutFlow_tables/MZD_91_SD_10.tex',
#  '2018_CutFlow_tables/MZD_91_SD_15.tex',
#  '2018_CutFlow_tables/MZD_91_SD_20.tex',
#  '2018_CutFlow_tables/MZD_91_SD_25.tex',
#  '2018_CutFlow_tables/MZD_91_SD_30.tex',
#  '2018_CutFlow_tables/MZD_91_SD_35.tex',
#  '2018_CutFlow_tables/MZD_91_SD_40.tex',
#  '2018_CutFlow_tables/MZD_91_SD_45.tex',
#  '2018_CutFlow_tables/MZD_91_SD_5.tex',
#  '2018_CutFlow_tables/MZD_95_MSD_10.tex',
#  '2018_CutFlow_tables/MZD_95_MSD_15.tex',
#  '2018_CutFlow_tables/MZD_95_MSD_20.tex',
#  '2018_CutFlow_tables/MZD_95_MSD_25.tex',
#  '2018_CutFlow_tables/MZD_95_MSD_30.tex',
#  '2018_CutFlow_tables/MZD_95_MSD_35.tex',
#  '2018_CutFlow_tables/MZD_95_MSD_40.tex',
#  '2018_CutFlow_tables/MZD_95_MSD_45.tex',
#  '2018_CutFlow_tables/MZD_95_MSD_5.tex',
#  '2018_CutFlow_tables/MZD_130_MSD_15.tex',
#  '2018_CutFlow_tables/MZD_130_MSD_20.tex',
#  '2018_CutFlow_tables/MZD_130_MSD_25.tex',
#  '2018_CutFlow_tables/MZD_130_MSD_30.tex',
#  '2018_CutFlow_tables/MZD_130_MSD_35.tex',
#  '2018_CutFlow_tables/MZD_130_MSD_40.tex',
#  '2018_CutFlow_tables/MZD_130_MSD_45.tex',
#  '2018_CutFlow_tables/MZD_130_MSD_5.tex',
#  '2018_CutFlow_tables/MZD_130_MSD_50.tex',
#  '2018_CutFlow_tables/MZD_130_MSD_55.tex',
#  '2018_CutFlow_tables/MZD_130_MSD_60.tex',
#  '2018_CutFlow_tables/MZD_130_MSD_65.tex',
#  '2018_CutFlow_tables/MZD_140_MSD_10.tex',
#  '2018_CutFlow_tables/MZD_140_MSD_15.tex',
#  '2018_CutFlow_tables/MZD_140_MSD_20.tex',
#  '2018_CutFlow_tables/MZD_140_MSD_25.tex',
#  '2018_CutFlow_tables/MZD_140_MSD_30.tex',
#  '2018_CutFlow_tables/MZD_140_MSD_35.tex',
#  '2018_CutFlow_tables/MZD_140_MSD_40.tex',
#  '2018_CutFlow_tables/MZD_140_MSD_45.tex',
#  '2018_CutFlow_tables/MZD_140_MSD_5.tex',
#  '2018_CutFlow_tables/MZD_140_MSD_50.tex',
#  '2018_CutFlow_tables/MZD_140_MSD_55.tex',
#  '2018_CutFlow_tables/MZD_140_MSD_60.tex',
#  '2018_CutFlow_tables/MZD_140_MSD_65.tex',
#  '2018_CutFlow_tables/MZD_140_MSD_70.tex',
#  '2018_CutFlow_tables/MZD_150_MSD_10.tex',
#  '2018_CutFlow_tables/MZD_150_MSD_15.tex',
#  '2018_CutFlow_tables/MZD_150_MSD_20.tex',
#  '2018_CutFlow_tables/MZD_150_MSD_25.tex',
#  '2018_CutFlow_tables/MZD_150_MSD_30.tex',
#  '2018_CutFlow_tables/MZD_150_MSD_35.tex',
#  '2018_CutFlow_tables/MZD_150_MSD_40.tex',
#  '2018_CutFlow_tables/MZD_150_MSD_45.tex',
#  '2018_CutFlow_tables/MZD_150_MSD_5.tex',
#  '2018_CutFlow_tables/MZD_150_MSD_50.tex',
#  '2018_CutFlow_tables/MZD_150_MSD_55.tex',
#  '2018_CutFlow_tables/MZD_150_MSD_60.tex',
#  '2018_CutFlow_tables/MZD_150_MSD_65.tex',
#  '2018_CutFlow_tables/MZD_150_MSD_70.tex',
#  '2018_CutFlow_tables/MZD_150_MSD_75.tex',
#  '2018_CutFlow_tables/MZD_170_MSD_15.tex',
#  '2018_CutFlow_tables/MZD_170_MSD_20.tex',
#  '2018_CutFlow_tables/MZD_170_MSD_30.tex',
#  '2018_CutFlow_tables/MZD_170_MSD_35.tex',
#  '2018_CutFlow_tables/MZD_170_MSD_40.tex',
#  '2018_CutFlow_tables/MZD_170_MSD_45.tex',
#  '2018_CutFlow_tables/MZD_170_MSD_5.tex',
#  '2018_CutFlow_tables/MZD_170_MSD_50.tex',
#  '2018_CutFlow_tables/MZD_170_MSD_55.tex',
#  '2018_CutFlow_tables/MZD_170_MSD_60.tex',
#  '2018_CutFlow_tables/MZD_170_MSD_70.tex',
#  '2018_CutFlow_tables/MZD_170_MSD_85.tex',
#  '2018_CutFlow_tables/MZD_180_MSD_10.tex',
#  '2018_CutFlow_tables/MZD_180_MSD_15.tex',
#  '2018_CutFlow_tables/MZD_180_MSD_20.tex',
#  '2018_CutFlow_tables/MZD_180_MSD_25.tex',
#  '2018_CutFlow_tables/MZD_180_MSD_30.tex',
#  '2018_CutFlow_tables/MZD_180_MSD_35.tex',
#  '2018_CutFlow_tables/MZD_180_MSD_40.tex',
#  '2018_CutFlow_tables/MZD_180_MSD_45.tex',
#  '2018_CutFlow_tables/MZD_180_MSD_5.tex',
#  '2018_CutFlow_tables/MZD_180_MSD_50.tex',
#  '2018_CutFlow_tables/MZD_180_MSD_55.tex',
#  '2018_CutFlow_tables/MZD_180_MSD_60.tex',
#  '2018_CutFlow_tables/MZD_180_MSD_70.tex',
#  '2018_CutFlow_tables/MZD_180_MSD_80.tex',
#  '2018_CutFlow_tables/MZD_180_MSD_90.tex',
#  '2018_CutFlow_tables/MZD_190_MSD_10.tex',
#  '2018_CutFlow_tables/MZD_190_MSD_15.tex',
#  '2018_CutFlow_tables/MZD_190_MSD_20.tex',
#  '2018_CutFlow_tables/MZD_190_MSD_25.tex',
#  '2018_CutFlow_tables/MZD_190_MSD_30.tex',
#  '2018_CutFlow_tables/MZD_190_MSD_35.tex',
#  '2018_CutFlow_tables/MZD_190_MSD_40.tex',
#  '2018_CutFlow_tables/MZD_190_MSD_45.tex',
#  '2018_CutFlow_tables/MZD_190_MSD_5.tex',
#  '2018_CutFlow_tables/MZD_190_MSD_50.tex',
#  '2018_CutFlow_tables/MZD_190_MSD_55.tex',
#  '2018_CutFlow_tables/MZD_190_MSD_60.tex',
#  '2018_CutFlow_tables/MZD_190_MSD_70.tex',
#  '2018_CutFlow_tables/MZD_190_MSD_80.tex',
#  '2018_CutFlow_tables/MZD_88_MSD_15.tex',
#  '2018_CutFlow_tables/MZD_88_MSD_20.tex',
#  '2018_CutFlow_tables/MZD_88_MSD_25.tex',
#  '2018_CutFlow_tables/MZD_88_MSD_30.tex',
#  '2018_CutFlow_tables/MZD_88_MSD_35.tex',
#  '2018_CutFlow_tables/MZD_88_MSD_40.tex',
#  '2018_CutFlow_tables/MZD_88_MSD_5.tex']

# %%
keys = [key.split(".")[0] for key in file_names] # return keys to be used in dictionary later

# %%
all_text = {} # to store all text from each file for further processing
for file in range(len(total_file_list)):
    with open(total_file_list[file], 'r') as text:
        all_text[total_file_list[file].split("/")[-1].split(".")[0]] = text.readlines()

# %% [markdown]
# # Processing ideas
# Files with MZD_YYY.tex have multiple samples with several $m_{S_{D}}$. Need to process these separately, as they are not all uniform and contain more than one cutflow table for different $m_{S_{D}}$.

# %%
class colors:
    WHITE   = '\033[97m'
    CYAN    = '\033[96m'
    MAGENTA = '\033[95m'
    BLUE    = '\033[94m'
    YELLOW  = '\033[93m'
    GREEN   = '\033[92m'
    RED     = '\033[91m'
    ORANGE  = '\033[38;5;208m'
    ENDC    = '\033[39m'
    
def print_info(string, color = colors.GREEN, endcolor = colors.ENDC):
    print(color + string + endcolor)   
    
def print_alert(string, color = colors.YELLOW, endcolor = colors.ENDC):
    print(color + string + endcolor)
    
def print_error(string, color = colors.RED, endcolor = colors.ENDC):
    print(color + string + endcolor)

# %% [markdown]
# # Final product

# %%
base_dirs = ["2017_CutFlow_tables/", "2018_CutFlow_tables/"]
base_dir  = base_dirs[1]
total_file_list, file_names = get_file_list(base_dir, ".tex")
keys = [key.split(".")[0] for key in file_names] # return keys to be used in dictionary later

# %%
keys_dict = {total_file_list[ii].split("/")[1].split(".")[0]: total_file_list[ii] for ii in range(len(total_file_list))}

# %%
keys_dict
# Out:
# {'MZD_100_MSD_50': '2018_CutFlow_tables/MZD_100_MSD_50.tex',
#  'MZD_100_SD_10': '2018_CutFlow_tables/MZD_100_SD_10.tex',
#  'MZD_100_SD_15': '2018_CutFlow_tables/MZD_100_SD_15.tex',
#  'MZD_100_SD_20': '2018_CutFlow_tables/MZD_100_SD_20.tex',
#  'MZD_100_SD_25': '2018_CutFlow_tables/MZD_100_SD_25.tex',
#  'MZD_100_SD_30': '2018_CutFlow_tables/MZD_100_SD_30.tex',
#  'MZD_100_SD_35': '2018_CutFlow_tables/MZD_100_SD_35.tex',
#  'MZD_100_SD_40': '2018_CutFlow_tables/MZD_100_SD_40.tex',
#  'MZD_100_SD_45': '2018_CutFlow_tables/MZD_100_SD_45.tex',
#  'MZD_100_SD_5': '2018_CutFlow_tables/MZD_100_SD_5.tex',
#  'MZD_110_MSD_10': '2018_CutFlow_tables/MZD_110_MSD_10.tex',
#  'MZD_110_MSD_15': '2018_CutFlow_tables/MZD_110_MSD_15.tex',
#  'MZD_110_MSD_20': '2018_CutFlow_tables/MZD_110_MSD_20.tex',
#  'MZD_110_MSD_25': '2018_CutFlow_tables/MZD_110_MSD_25.tex',
#  'MZD_110_MSD_30': '2018_CutFlow_tables/MZD_110_MSD_30.tex',
#  'MZD_110_MSD_35': '2018_CutFlow_tables/MZD_110_MSD_35.tex',
#  'MZD_110_MSD_40': '2018_CutFlow_tables/MZD_110_MSD_40.tex',
#  'MZD_110_MSD_45': '2018_CutFlow_tables/MZD_110_MSD_45.tex',
#  'MZD_110_MSD_5': '2018_CutFlow_tables/MZD_110_MSD_5.tex',
#  'MZD_110_MSD_50': '2018_CutFlow_tables/MZD_110_MSD_50.tex',
#  'MZD_110_MSD_55': '2018_CutFlow_tables/MZD_110_MSD_55.tex',
#  'MZD_125_MSD_10': '2018_CutFlow_tables/MZD_125_MSD_10.tex',
#  'MZD_125_MSD_20': '2018_CutFlow_tables/MZD_125_MSD_20.tex',
#  'MZD_125_MSD_40': '2018_CutFlow_tables/MZD_125_MSD_40.tex',
#  'MZD_125_SD_15': '2018_CutFlow_tables/MZD_125_SD_15.tex',
#  'MZD_125_SD_25': '2018_CutFlow_tables/MZD_125_SD_25.tex',
#  'MZD_125_SD_30': '2018_CutFlow_tables/MZD_125_SD_30.tex',
#  'MZD_125_SD_35': '2018_CutFlow_tables/MZD_125_SD_35.tex',
#  'MZD_125_SD_45': '2018_CutFlow_tables/MZD_125_SD_45.tex',
#  'MZD_125_SD_5': '2018_CutFlow_tables/MZD_125_SD_5.tex',
#  'MZD_125_SD_50': '2018_CutFlow_tables/MZD_125_SD_50.tex',
#  'MZD_125_SD_55': '2018_CutFlow_tables/MZD_125_SD_55.tex',
#  'MZD_125_SD_60': '2018_CutFlow_tables/MZD_125_SD_60.tex',
#  'MZD_130_MSD_10': '2018_CutFlow_tables/MZD_130_MSD_10.tex',
#  'MZD_160_MSD_10': '2018_CutFlow_tables/MZD_160_MSD_10.tex',
#  'MZD_160_MSD_15': '2018_CutFlow_tables/MZD_160_MSD_15.tex',
#  'MZD_160_MSD_20': '2018_CutFlow_tables/MZD_160_MSD_20.tex',
#  'MZD_160_MSD_25': '2018_CutFlow_tables/MZD_160_MSD_25.tex',
#  'MZD_160_MSD_30': '2018_CutFlow_tables/MZD_160_MSD_30.tex',
#  'MZD_160_MSD_35': '2018_CutFlow_tables/MZD_160_MSD_35.tex',
#  'MZD_160_MSD_40': '2018_CutFlow_tables/MZD_160_MSD_40.tex',
#  'MZD_160_MSD_45': '2018_CutFlow_tables/MZD_160_MSD_45.tex',
#  'MZD_160_MSD_5': '2018_CutFlow_tables/MZD_160_MSD_5.tex',
#  'MZD_160_MSD_50': '2018_CutFlow_tables/MZD_160_MSD_50.tex',
#  'MZD_160_MSD_55': '2018_CutFlow_tables/MZD_160_MSD_55.tex',
#  'MZD_160_MSD_60': '2018_CutFlow_tables/MZD_160_MSD_60.tex',
#  'MZD_160_MSD_70': '2018_CutFlow_tables/MZD_160_MSD_70.tex',
#  'MZD_160_MSD_80': '2018_CutFlow_tables/MZD_160_MSD_80.tex',
#  'MZD_200_MSD_15': '2018_CutFlow_tables/MZD_200_MSD_15.tex',
#  'MZD_200_MSD_25': '2018_CutFlow_tables/MZD_200_MSD_25.tex',
#  'MZD_200_MSD_35': '2018_CutFlow_tables/MZD_200_MSD_35.tex',
#  'MZD_200_MSD_45': '2018_CutFlow_tables/MZD_200_MSD_45.tex',
#  'MZD_200_MSD_55': '2018_CutFlow_tables/MZD_200_MSD_55.tex',
#  'MZD_200_SD_10': '2018_CutFlow_tables/MZD_200_SD_10.tex',
#  'MZD_200_SD_100': '2018_CutFlow_tables/MZD_200_SD_100.tex',
#  'MZD_200_SD_20': '2018_CutFlow_tables/MZD_200_SD_20.tex',
#  'MZD_200_SD_30': '2018_CutFlow_tables/MZD_200_SD_30.tex',
#  'MZD_200_SD_40': '2018_CutFlow_tables/MZD_200_SD_40.tex',
#  'MZD_200_SD_5': '2018_CutFlow_tables/MZD_200_SD_5.tex',
#  'MZD_200_SD_50': '2018_CutFlow_tables/MZD_200_SD_50.tex',
#  'MZD_200_SD_60': '2018_CutFlow_tables/MZD_200_SD_60.tex',
#  'MZD_200_SD_80': '2018_CutFlow_tables/MZD_200_SD_80.tex',
#  'MZD_80_MSD_35': '2018_CutFlow_tables/MZD_80_MSD_35.tex',
#  'MZD_80_SD_10': '2018_CutFlow_tables/MZD_80_SD_10.tex',
#  'MZD_80_SD_15': '2018_CutFlow_tables/MZD_80_SD_15.tex',
#  'MZD_80_SD_20': '2018_CutFlow_tables/MZD_80_SD_20.tex',
#  'MZD_80_SD_25': '2018_CutFlow_tables/MZD_80_SD_25.tex',
#  'MZD_80_SD_30': '2018_CutFlow_tables/MZD_80_SD_30.tex',
#  'MZD_80_SD_35': '2018_CutFlow_tables/MZD_80_SD_35.tex',
#  'MZD_80_SD_5': '2018_CutFlow_tables/MZD_80_SD_5.tex',
#  'MZD_85_MSD_10': '2018_CutFlow_tables/MZD_85_MSD_10.tex',
#  'MZD_85_MSD_15': '2018_CutFlow_tables/MZD_85_MSD_15.tex',
#  'MZD_85_MSD_20': '2018_CutFlow_tables/MZD_85_MSD_20.tex',
#  'MZD_85_MSD_25': '2018_CutFlow_tables/MZD_85_MSD_25.tex',
#  'MZD_85_MSD_30': '2018_CutFlow_tables/MZD_85_MSD_30.tex',
#  'MZD_85_MSD_35': '2018_CutFlow_tables/MZD_85_MSD_35.tex',
#  'MZD_85_MSD_40': '2018_CutFlow_tables/MZD_85_MSD_40.tex',
#  'MZD_85_MSD_5': '2018_CutFlow_tables/MZD_85_MSD_5.tex',
#  'MZD_91_SD_10': '2018_CutFlow_tables/MZD_91_SD_10.tex',
#  'MZD_91_SD_15': '2018_CutFlow_tables/MZD_91_SD_15.tex',
#  'MZD_91_SD_20': '2018_CutFlow_tables/MZD_91_SD_20.tex',
#  'MZD_91_SD_25': '2018_CutFlow_tables/MZD_91_SD_25.tex',
#  'MZD_91_SD_30': '2018_CutFlow_tables/MZD_91_SD_30.tex',
#  'MZD_91_SD_35': '2018_CutFlow_tables/MZD_91_SD_35.tex',
#  'MZD_91_SD_40': '2018_CutFlow_tables/MZD_91_SD_40.tex',
#  'MZD_91_SD_45': '2018_CutFlow_tables/MZD_91_SD_45.tex',
#  'MZD_91_SD_5': '2018_CutFlow_tables/MZD_91_SD_5.tex',
#  'MZD_95_MSD_10': '2018_CutFlow_tables/MZD_95_MSD_10.tex',
#  'MZD_95_MSD_15': '2018_CutFlow_tables/MZD_95_MSD_15.tex',
#  'MZD_95_MSD_20': '2018_CutFlow_tables/MZD_95_MSD_20.tex',
#  'MZD_95_MSD_25': '2018_CutFlow_tables/MZD_95_MSD_25.tex',
#  'MZD_95_MSD_30': '2018_CutFlow_tables/MZD_95_MSD_30.tex',
#  'MZD_95_MSD_35': '2018_CutFlow_tables/MZD_95_MSD_35.tex',
#  'MZD_95_MSD_40': '2018_CutFlow_tables/MZD_95_MSD_40.tex',
#  'MZD_95_MSD_45': '2018_CutFlow_tables/MZD_95_MSD_45.tex',
#  'MZD_95_MSD_5': '2018_CutFlow_tables/MZD_95_MSD_5.tex',
#  'MZD_130_MSD_15': '2018_CutFlow_tables/MZD_130_MSD_15.tex',
#  'MZD_130_MSD_20': '2018_CutFlow_tables/MZD_130_MSD_20.tex',
#  'MZD_130_MSD_25': '2018_CutFlow_tables/MZD_130_MSD_25.tex',
#  'MZD_130_MSD_30': '2018_CutFlow_tables/MZD_130_MSD_30.tex',
#  'MZD_130_MSD_35': '2018_CutFlow_tables/MZD_130_MSD_35.tex',
#  'MZD_130_MSD_40': '2018_CutFlow_tables/MZD_130_MSD_40.tex',
#  'MZD_130_MSD_45': '2018_CutFlow_tables/MZD_130_MSD_45.tex',
#  'MZD_130_MSD_5': '2018_CutFlow_tables/MZD_130_MSD_5.tex',
#  'MZD_130_MSD_50': '2018_CutFlow_tables/MZD_130_MSD_50.tex',
#  'MZD_130_MSD_55': '2018_CutFlow_tables/MZD_130_MSD_55.tex',
#  'MZD_130_MSD_60': '2018_CutFlow_tables/MZD_130_MSD_60.tex',
#  'MZD_130_MSD_65': '2018_CutFlow_tables/MZD_130_MSD_65.tex',
#  'MZD_140_MSD_10': '2018_CutFlow_tables/MZD_140_MSD_10.tex',
#  'MZD_140_MSD_15': '2018_CutFlow_tables/MZD_140_MSD_15.tex',
#  'MZD_140_MSD_20': '2018_CutFlow_tables/MZD_140_MSD_20.tex',
#  'MZD_140_MSD_25': '2018_CutFlow_tables/MZD_140_MSD_25.tex',
#  'MZD_140_MSD_30': '2018_CutFlow_tables/MZD_140_MSD_30.tex',
#  'MZD_140_MSD_35': '2018_CutFlow_tables/MZD_140_MSD_35.tex',
#  'MZD_140_MSD_40': '2018_CutFlow_tables/MZD_140_MSD_40.tex',
#  'MZD_140_MSD_45': '2018_CutFlow_tables/MZD_140_MSD_45.tex',
#  'MZD_140_MSD_5': '2018_CutFlow_tables/MZD_140_MSD_5.tex',
#  'MZD_140_MSD_50': '2018_CutFlow_tables/MZD_140_MSD_50.tex',
#  'MZD_140_MSD_55': '2018_CutFlow_tables/MZD_140_MSD_55.tex',
#  'MZD_140_MSD_60': '2018_CutFlow_tables/MZD_140_MSD_60.tex',
#  'MZD_140_MSD_65': '2018_CutFlow_tables/MZD_140_MSD_65.tex',
#  'MZD_140_MSD_70': '2018_CutFlow_tables/MZD_140_MSD_70.tex',
#  'MZD_150_MSD_10': '2018_CutFlow_tables/MZD_150_MSD_10.tex',
#  'MZD_150_MSD_15': '2018_CutFlow_tables/MZD_150_MSD_15.tex',
#  'MZD_150_MSD_20': '2018_CutFlow_tables/MZD_150_MSD_20.tex',
#  'MZD_150_MSD_25': '2018_CutFlow_tables/MZD_150_MSD_25.tex',
#  'MZD_150_MSD_30': '2018_CutFlow_tables/MZD_150_MSD_30.tex',
#  'MZD_150_MSD_35': '2018_CutFlow_tables/MZD_150_MSD_35.tex',
#  'MZD_150_MSD_40': '2018_CutFlow_tables/MZD_150_MSD_40.tex',
#  'MZD_150_MSD_45': '2018_CutFlow_tables/MZD_150_MSD_45.tex',
#  'MZD_150_MSD_5': '2018_CutFlow_tables/MZD_150_MSD_5.tex',
#  'MZD_150_MSD_50': '2018_CutFlow_tables/MZD_150_MSD_50.tex',
#  'MZD_150_MSD_55': '2018_CutFlow_tables/MZD_150_MSD_55.tex',
#  'MZD_150_MSD_60': '2018_CutFlow_tables/MZD_150_MSD_60.tex',
#  'MZD_150_MSD_65': '2018_CutFlow_tables/MZD_150_MSD_65.tex',
#  'MZD_150_MSD_70': '2018_CutFlow_tables/MZD_150_MSD_70.tex',
#  'MZD_150_MSD_75': '2018_CutFlow_tables/MZD_150_MSD_75.tex',
#  'MZD_170_MSD_15': '2018_CutFlow_tables/MZD_170_MSD_15.tex',
#  'MZD_170_MSD_20': '2018_CutFlow_tables/MZD_170_MSD_20.tex',
#  'MZD_170_MSD_30': '2018_CutFlow_tables/MZD_170_MSD_30.tex',
#  'MZD_170_MSD_35': '2018_CutFlow_tables/MZD_170_MSD_35.tex',
#  'MZD_170_MSD_40': '2018_CutFlow_tables/MZD_170_MSD_40.tex',
#  'MZD_170_MSD_45': '2018_CutFlow_tables/MZD_170_MSD_45.tex',
#  'MZD_170_MSD_5': '2018_CutFlow_tables/MZD_170_MSD_5.tex',
#  'MZD_170_MSD_50': '2018_CutFlow_tables/MZD_170_MSD_50.tex',
#  'MZD_170_MSD_55': '2018_CutFlow_tables/MZD_170_MSD_55.tex',
#  'MZD_170_MSD_60': '2018_CutFlow_tables/MZD_170_MSD_60.tex',
#  'MZD_170_MSD_70': '2018_CutFlow_tables/MZD_170_MSD_70.tex',
#  'MZD_170_MSD_85': '2018_CutFlow_tables/MZD_170_MSD_85.tex',
#  'MZD_180_MSD_10': '2018_CutFlow_tables/MZD_180_MSD_10.tex',
#  'MZD_180_MSD_15': '2018_CutFlow_tables/MZD_180_MSD_15.tex',
#  'MZD_180_MSD_20': '2018_CutFlow_tables/MZD_180_MSD_20.tex',
#  'MZD_180_MSD_25': '2018_CutFlow_tables/MZD_180_MSD_25.tex',
#  'MZD_180_MSD_30': '2018_CutFlow_tables/MZD_180_MSD_30.tex',
#  'MZD_180_MSD_35': '2018_CutFlow_tables/MZD_180_MSD_35.tex',
#  'MZD_180_MSD_40': '2018_CutFlow_tables/MZD_180_MSD_40.tex',
#  'MZD_180_MSD_45': '2018_CutFlow_tables/MZD_180_MSD_45.tex',
#  'MZD_180_MSD_5': '2018_CutFlow_tables/MZD_180_MSD_5.tex',
#  'MZD_180_MSD_50': '2018_CutFlow_tables/MZD_180_MSD_50.tex',
#  'MZD_180_MSD_55': '2018_CutFlow_tables/MZD_180_MSD_55.tex',
#  'MZD_180_MSD_60': '2018_CutFlow_tables/MZD_180_MSD_60.tex',
#  'MZD_180_MSD_70': '2018_CutFlow_tables/MZD_180_MSD_70.tex',
#  'MZD_180_MSD_80': '2018_CutFlow_tables/MZD_180_MSD_80.tex',
#  'MZD_180_MSD_90': '2018_CutFlow_tables/MZD_180_MSD_90.tex',
#  'MZD_190_MSD_10': '2018_CutFlow_tables/MZD_190_MSD_10.tex',
#  'MZD_190_MSD_15': '2018_CutFlow_tables/MZD_190_MSD_15.tex',
#  'MZD_190_MSD_20': '2018_CutFlow_tables/MZD_190_MSD_20.tex',
#  'MZD_190_MSD_25': '2018_CutFlow_tables/MZD_190_MSD_25.tex',
#  'MZD_190_MSD_30': '2018_CutFlow_tables/MZD_190_MSD_30.tex',
#  'MZD_190_MSD_35': '2018_CutFlow_tables/MZD_190_MSD_35.tex',
#  'MZD_190_MSD_40': '2018_CutFlow_tables/MZD_190_MSD_40.tex',
#  'MZD_190_MSD_45': '2018_CutFlow_tables/MZD_190_MSD_45.tex',
#  'MZD_190_MSD_5': '2018_CutFlow_tables/MZD_190_MSD_5.tex',
#  'MZD_190_MSD_50': '2018_CutFlow_tables/MZD_190_MSD_50.tex',
#  'MZD_190_MSD_55': '2018_CutFlow_tables/MZD_190_MSD_55.tex',
#  'MZD_190_MSD_60': '2018_CutFlow_tables/MZD_190_MSD_60.tex',
#  'MZD_190_MSD_70': '2018_CutFlow_tables/MZD_190_MSD_70.tex',
#  'MZD_190_MSD_80': '2018_CutFlow_tables/MZD_190_MSD_80.tex',
#  'MZD_88_MSD_15': '2018_CutFlow_tables/MZD_88_MSD_15.tex',
#  'MZD_88_MSD_20': '2018_CutFlow_tables/MZD_88_MSD_20.tex',
#  'MZD_88_MSD_25': '2018_CutFlow_tables/MZD_88_MSD_25.tex',
#  'MZD_88_MSD_30': '2018_CutFlow_tables/MZD_88_MSD_30.tex',
#  'MZD_88_MSD_35': '2018_CutFlow_tables/MZD_88_MSD_35.tex',
#  'MZD_88_MSD_40': '2018_CutFlow_tables/MZD_88_MSD_40.tex',
#  'MZD_88_MSD_5': '2018_CutFlow_tables/MZD_88_MSD_5.tex'}

# %%
global dataDir 
dataDir = "2018_cutflow_csv/"

# %%
def process_cutflow(file_list, to_pandas = True, save_csv = True, ret = True, verbose = False):
    '''
     S. D. Butalla
    2022/08/19 - v0
    
    Function that, given a list absolute file paths (.tex or .txt) 
    for cutflow tables, parses the files and stores the cutflow 
    tables in a dictionary (key = file name without extension).
    By default, the function places the extracted cutflow
    table in a pandas dataframe and saves the table to a 
    .csv.
    
    Dependencies:
    
    pandas
    re
    
    colors (custom class)
    
    Positional arguments:
    file_list          : (list; string) A list of the absolute file
                         paths for the cutflow table files.
                         
    Optional arguments:
    to_pandas          : (bool) If true, will convert each cutflow table
                         stored in a dictionary to a pandas dataframe. 
    save_csv           : (bool) If true, will save the pandas dataframe
                         as a .csv in the specified data directory
                         ('dataDir').
    ret                : (bool) If true, will return the various outputs
                         (see below).
    verbose            : (bool) If true, will print extra information.
    
    Output:
    cutflow_dict       : (dict) Dictionary of all cutflow tables. Keys are
                         the names of the files in the file list (without
                         the path or the file extension).
    epsilon_alpha      : (dict) Dictionary of the epsilon / alpha value
                         (keys are the same as in cutflow_dict).
    epsilon_alpha_err  : (dict) Dictionary of the epsilon / alpha
                         uncertainties (keys are the same as in cutflow_dict).
    Optional output:
    df_dict            : (dict) Dictionary of pandas dataframes of the cutflow
                         tables.
    '''
    
    if save_csv and not to_pandas:
        print_error("To save cutflow table as a csv the result dictionary must be converted to a pandas dataframe first. Set to_pandas = True.")
        
    verbose    = True
    
    keys_dict         = {file_list[ii].split("/")[1].split(".")[0]: file_list[ii] for ii in range(len(file_list))} # dict of key: file path
    cutflow_dict      = {} # stores all cutflow table information
    epsilon_alpha     = {} # stores all epsilon / alpha values
    epsilon_alpha_err = {} # stores all epsilon / alpha errors
    
    if to_pandas:
        df_dict = {}
    
    for key in keys_dict.keys():
        cut_num                = []
        selection              = []
        events                 = []
        tot_eff                = []
        rel_eff                = []
        tot_eff_err            = []
        rel_eff_err            = []
        cutflow_dict[key]      = {} # stores all cutflow table information
        epsilon_alpha[key]     = {} # stores all epsilon / alpha values
        epsilon_alpha_err[key] = {} # stores all epsilon / alpha errors
        
        if verbose:
            print_alert("Opening file %s\n" % keys_dict[key])
            
        file  = open(keys_dict[key])
        
        if verbose:
            print_alert("File opened successfully\n")
        
        lines = file.readlines()
        
        if verbose:
            print_alert("Processing file...")
        
        cnt = 0
        for line in lines:
            if line == "Here is the cut-flow-table:\n":
                if verbose:
                    print_alert("Cutflow table detected, processing...\n")
                cnt_data = 0 # counter to keep track of line number
                for data in lines[(cnt + 6):]: # iterate over the table data
                    if re.split('(\d+)', re.sub('[^A-Za-z0-9]+', '', data.split("&")[0]))[0] == "epsilonrecalphagen": # find end of table and extract epsilon/alpha and error
                        epsilonalpha    = data.split("&")[1].split("$")[0].strip()                   # clean text and formatting characters, strip spaces
                        epsilonalphaerr = data.split("&")[1].split("$")[2].split("hline")[0].strip() # clean text and formatting characters, strip spaces
                        
                        # Check for results (some tables don't have epsilon/alpha error vals)
                        if len(epsilonalpha) != 0:
                            epsilon_alpha[key] = float(epsilonalpha)
                        else:
                            epsilon_alpha[key] = None
                        
                        if len(epsilonalphaerr) != 0:
                            epsilon_alpha_err[key] = float(epsilonalphaerr)
                        else:
                            epsilon_alpha_err[key] = None    
                                                    
                        if verbose:
                            print_alert("Epsilon/alpha values:")
                            print_alert(21 * "*")
                            if type(epsilon_alpha[key]) is float:
                                print_alert("eps/alp = %f" % epsilon_alpha[key])
                            elif type(epsilon_alpha[key]) is None:
                                print_alert("eps/alp not in cutflow table")
                            
                            if type(epsilon_alpha_err[key]) is float:
                                print_alert("eps/alp err = %f" % epsilon_alpha_err[key])
                            elif type(epsilon_alpha_err[key]) is None:
                                 print_alert("eps/alp error not in cutflow table")
                            
                            print_alert(21 * "*" + "\n")
                                    
                        continue
                    else:
                        temp_str = data.split("&") # split data into list based on LaTeX alignment character '&'
                        if len(temp_str) == 1:     # Skip blank rows of the table (between gen and reco cuts, and reco cuts and epsilon/alpha) 
                            pass
                        else:
                            if cnt_data == 0:
                                header_lst = []
                                cnt_hdr    = 0
                                for text in temp_str:
                                    if cnt_hdr == 5:
                                        header_lst.append(re.split('(\d+)', re.sub('[^A-Za-z0-9]+', '', text.split("hline")[0]))) # remove LaTeX formatting command "hline" and newline characters
                                    else:
                                        header_lst.append(re.split('(\d+)', re.sub('[^A-Za-z0-9]+', '', text))) # remove spaces and special characters

                                    cnt_hdr += 1

                                header_titles = list(itertools.chain.from_iterable(header_lst)) # flatten list 
                                header_titles.insert(0, "CutNum") # Only '#' is present for the cut number, this is removing during the sub./split process, so add a string title
                                cnt_data += 1
                            elif cnt_data > 0: 
                                cut_number  = re.sub('[^A-Za-z0-9]+', '', temp_str[0].split(" ")[1])
                                cut_type = temp_str[0].split(" ")[3]

                                if len(temp_str) == 1:
                                    if re.sub('[^A-Za-z0-9]+', '', temp_str[0]) == "endtabular":
                                        if verbose:
                                            print_alert("End of table reached!\n")
                                        continue
                                else:
                                    cut_num.append(int(cut_number))
                                    selection.append(cut_type)
                                    #cut_num.append(first_two_cols[0])                     # COLUMN 0: store cut num as str
                                    #selection.append(first_two_cols[1])                        # COLUMN 0: store selection/cut type as str
                                    events.append(int(temp_str[1]))                            # COLUMN 2: store num events as int
                                    tot_eff.append(float(temp_str[2]))                         # COLUMN 3: store tot. eff. as float
                                    rel_eff.append(float(temp_str[3]))                         # COLUMN 4: store rel. eff. as float
                                    tot_eff_err.append(float(temp_str[4]))                     # COLUMN 5: store tot. eff. err. as float
                                    rel_eff_err.append(float(temp_str[5].split("hline")[0]))   # COLUMN 5: clean LaTeX formatting and store rel. eff. err. as float
                                    cnt_data += 1

                    data_lists = [cut_num, selection, events, tot_eff, rel_eff, tot_eff_err, rel_eff_err] # store all lists to make filling dictionary easier

                    dict_cnt = 0
                    for datum in data_lists: # fill dictionary with lists
                        cutflow_dict[key][header_titles[dict_cnt]] = datum
                        dict_cnt += 1

                    cnt += 1
            cnt += 1
            
        if to_pandas:
            if verbose:
                print_alert("Transferring dictionary to pandas dataframe\n")
            
            df_dict[key] = pd.DataFrame.from_dict(cutflow_dict[key])
            
            if save_csv:
                file_name = dataDir + "dataframe_%s.csv" % key
                if verbose:
                    print_alert("Saving pandas dataframe to %s\n" % file_name)
                
                df_dict[key].to_csv(file_name)
        
        
        file.close()
        
        if verbose:
            print_alert("File closed successfully\n\n\n\n")
    
    if ret:
        if to_pandas:
            return cutflow_dict, df_dict, epsilon_alpha, epsilon_alpha_err
        else:
            return cutflow_dict, epsilon_alpha, epsilon_alpha_err

# %%
cutflow_dict_2018, df_dict_2018, epsilon_alpha_2018, epsilon_alpha_err_2018 = process_cutflow(total_file_list, verbose = True)
# Out:
# Opening file 2018_CutFlow_tables/MZD_100_MSD_50.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.454000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_100_MSD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_100_SD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.000000
# eps/alp err = nan
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_100_SD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_100_SD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.413000
# eps/alp err = 0.022100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_100_SD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_100_SD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.435000
# eps/alp err = 0.023900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_100_SD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_100_SD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.418000
# eps/alp err = 0.024100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_100_SD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_100_SD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.421000
# eps/alp err = 0.024500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_100_SD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_100_SD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.403000
# eps/alp err = 0.022300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_100_SD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_100_SD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.419000
# eps/alp err = 0.020600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_100_SD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_100_SD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.440000
# eps/alp err = 0.020400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_100_SD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_100_SD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.432000
# eps/alp err = 0.022100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_100_SD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_110_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.003660
# eps/alp err = 0.001500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_110_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_110_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.402000
# eps/alp err = 0.018800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_110_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_110_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.425000
# eps/alp err = 0.019900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_110_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_110_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.407000
# eps/alp err = 0.019600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_110_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_110_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.399000
# eps/alp err = 0.019800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_110_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_110_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.419000
# eps/alp err = 0.019600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_110_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_110_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.425000
# eps/alp err = 0.018400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_110_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_110_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.426000
# eps/alp err = 0.017100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_110_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_110_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.419000
# eps/alp err = 0.019300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_110_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_110_MSD_50.tex
#
# File opened successfully
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.412000
# eps/alp err = 0.016500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_110_MSD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_110_MSD_55.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.429000
# eps/alp err = 0.015400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_110_MSD_55.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_125_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.000483
# eps/alp err = 0.000483
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_125_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_125_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.421000
# eps/alp err = 0.017600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_125_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_125_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.419000
# eps/alp err = 0.016500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_125_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_125_SD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.405000
# eps/alp err = 0.016700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_125_SD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_125_SD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.418000
# eps/alp err = 0.017700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_125_SD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_125_SD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.391000
# eps/alp err = 0.016900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_125_SD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_125_SD_35.tex
#
# File opened successfully
#
# Processing file...
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_125_SD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_125_SD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.401000
# eps/alp err = 0.015000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_125_SD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_125_SD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.412000
# eps/alp err = 0.016800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_125_SD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_125_SD_50.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.401000
# eps/alp err = 0.014700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_125_SD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_125_SD_55.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.416000
# eps/alp err = 0.014800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_125_SD_55.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_125_SD_60.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.167000
# eps/alp err = 0.008140
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_125_SD_60.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_130_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.002660
# eps/alp err = 0.001090
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_130_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_160_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.000699
# eps/alp err = 0.000494
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_160_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_160_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.396000
# eps/alp err = 0.013900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_160_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_160_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.376000
# eps/alp err = 0.013700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_160_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_160_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.395000
# eps/alp err = 0.014200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_160_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_160_MSD_30.tex
#
# File opened successfully
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.382000
# eps/alp err = 0.014200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_160_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_160_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.389000
# eps/alp err = 0.013900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_160_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_160_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.388000
# eps/alp err = 0.013800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_160_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_160_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.392000
# eps/alp err = 0.013600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_160_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_160_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.402000
# eps/alp err = 0.014000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_160_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_160_MSD_50.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.391000
# eps/alp err = 0.013100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_160_MSD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_160_MSD_55.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.419000
# eps/alp err = 0.014100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_160_MSD_55.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_160_MSD_60.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.133000
# eps/alp err = 0.006640
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_160_MSD_60.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_160_MSD_70.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.010100
# eps/alp err = 0.001680
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_160_MSD_70.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_160_MSD_80.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.194000
# eps/alp err = 0.007670
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_160_MSD_80.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_200_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.396000
# eps/alp err = 0.012700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_200_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_200_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.393000
# eps/alp err = 0.012600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_200_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_200_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.388000
# eps/alp err = 0.012700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_200_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_200_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.408000
# eps/alp err = 0.013000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_200_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_200_MSD_55.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.387000
# eps/alp err = 0.012100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_200_MSD_55.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_200_SD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.000563
# eps/alp err = 0.000398
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_200_SD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_200_SD_100.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.000936
# eps/alp err = 0.000468
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_200_SD_100.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_200_SD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.388000
# eps/alp err = 0.012300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_200_SD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_200_SD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.377000
# eps/alp err = 0.012300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_200_SD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_200_SD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.383000
# eps/alp err = 0.012500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_200_SD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_200_SD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.391000
# eps/alp err = 0.012400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_200_SD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_200_SD_50.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.384000
# eps/alp err = 0.012300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_200_SD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_200_SD_60.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.127000
# eps/alp err = 0.006180
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_200_SD_60.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_200_SD_80.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.000246
# eps/alp err = 0.000246
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_200_SD_80.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_80_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_80_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_80_SD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.003770
# eps/alp err = 0.003780
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_80_SD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_80_SD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.450000
# eps/alp err = 0.055600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_80_SD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_80_SD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.405000
# eps/alp err = 0.052700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_80_SD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_80_SD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.407000
# eps/alp err = 0.056900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_80_SD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_80_SD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.413000
# eps/alp err = 0.051000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_80_SD_30.csv
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_80_SD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.429000
# eps/alp err = 0.041700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_80_SD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_80_SD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.406000
# eps/alp err = 0.044900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_80_SD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_85_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.003980
# eps/alp err = 0.002820
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_85_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_85_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.418000
# eps/alp err = 0.040000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_85_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_85_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.421000
# eps/alp err = 0.039700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_85_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_85_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.508000
# eps/alp err = 0.049500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_85_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_85_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.422000
# eps/alp err = 0.038000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_85_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_85_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.417000
# eps/alp err = 0.032500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_85_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_85_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.502000
# eps/alp err = 0.041000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_85_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_85_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.446000
# eps/alp err = 0.035000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_85_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_91_SD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.004020
# eps/alp err = 0.002320
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_91_SD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_91_SD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.437000
# eps/alp err = 0.029800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_91_SD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_91_SD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.412000
# eps/alp err = 0.030800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_91_SD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_91_SD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.432000
# eps/alp err = 0.033200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_91_SD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_91_SD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.412000
# eps/alp err = 0.033200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_91_SD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_91_SD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.410000
# eps/alp err = 0.026000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_91_SD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_91_SD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.419000
# eps/alp err = 0.024600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_91_SD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_91_SD_45.tex
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.467000
# eps/alp err = 0.034500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_91_SD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_91_SD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.454000
# eps/alp err = 0.027900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_91_SD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_95_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.008320
# eps/alp err = 0.002950
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_95_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_95_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.426000
# eps/alp err = 0.026200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_95_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_95_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.453000
# eps/alp err = 0.029200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_95_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_95_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.434000
# eps/alp err = 0.028300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_95_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_95_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.399000
# eps/alp err = 0.026700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_95_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_95_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.435000
# eps/alp err = 0.024900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_95_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_95_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.447000
# eps/alp err = 0.023100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_95_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_95_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.463000
# eps/alp err = 0.025400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_95_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_95_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.443000
# eps/alp err = 0.025100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_95_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_130_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.416000
# eps/alp err = 0.016400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_130_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_130_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.402000
# eps/alp err = 0.016400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_130_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_130_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.383000
# eps/alp err = 0.016300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_130_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_130_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.395000
# eps/alp err = 0.016600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_130_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_130_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.384000
# eps/alp err = 0.015800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_130_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_130_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.402000
# eps/alp err = 0.015600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_130_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_130_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.406000
# eps/alp err = 0.014900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_130_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_130_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.406000
# eps/alp err = 0.015700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_130_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_130_MSD_50.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.408000
# eps/alp err = 0.014500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_130_MSD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_130_MSD_55.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.425000
# eps/alp err = 0.014700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_130_MSD_55.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_130_MSD_60.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.145000
# eps/alp err = 0.007540
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_130_MSD_60.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_130_MSD_65.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.332000
# eps/alp err = 0.011400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_130_MSD_65.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_140_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.002090
# eps/alp err = 0.000935
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_140_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_140_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.394000
# eps/alp err = 0.015400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_140_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_140_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.401000
# eps/alp err = 0.015400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_140_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_140_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.401000
# eps/alp err = 0.015500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_140_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_140_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.419000
# eps/alp err = 0.015900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_140_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_140_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.414000
# eps/alp err = 0.015900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_140_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_140_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.408000
# eps/alp err = 0.015300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_140_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_140_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.404000
# eps/alp err = 0.014400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_140_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_140_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.407000
# eps/alp err = 0.015400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_140_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_140_MSD_50.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.407000
# eps/alp err = 0.013900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_140_MSD_50.csv
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_140_MSD_55.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.413000
# eps/alp err = 0.013900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_140_MSD_55.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_140_MSD_60.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.146000
# eps/alp err = 0.007390
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_140_MSD_60.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_140_MSD_65.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.016900
# eps/alp err = 0.002320
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_140_MSD_65.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_140_MSD_70.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.276000
# eps/alp err = 0.010000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_140_MSD_70.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_150_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.001890
# eps/alp err = 0.000846
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_150_MSD_10.csv
#
# File closed successfully
#
#
#
#
# ...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.414000
# eps/alp err = 0.013600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_170_MSD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_170_MSD_55.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.405000
# eps/alp err = 0.012800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_170_MSD_55.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_170_MSD_60.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.129000
# eps/alp err = 0.006380
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_170_MSD_60.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_170_MSD_70.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.009640
# eps/alp err = 0.001610
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_170_MSD_70.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_170_MSD_85.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.179000
# eps/alp err = 0.007280
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_170_MSD_85.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_180_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.000313
# eps/alp err = 0.000313
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_180_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_180_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.382000
# eps/alp err = 0.013000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_180_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_180_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.394000
# eps/alp err = 0.013200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_180_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_180_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.385000
# eps/alp err = 0.013300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_180_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_180_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.392000
# eps/alp err = 0.013300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_180_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_180_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.396000
# eps/alp err = 0.013600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_180_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_180_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.386000
# eps/alp err = 0.013000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_180_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_180_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.392000
# eps/alp err = 0.013000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_180_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_180_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.387000
# eps/alp err = 0.012800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_180_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_180_MSD_50.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.381000
# eps/alp err = 0.012400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_180_MSD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_180_MSD_55.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.387000
# eps/alp err = 0.012200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_180_MSD_55.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_180_MSD_60.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.133000
# eps/alp err = 0.006420
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_180_MSD_60.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_180_MSD_70.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.008000
# eps/alp err = 0.001470
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_180_MSD_70.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_180_MSD_80.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.008740
# eps/alp err = 0.001480
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_180_MSD_80.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_180_MSD_90.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.158000
# eps/alp err = 0.006690
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_180_MSD_90.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_190_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.000000
# eps/alp err = nan
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_190_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_190_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.404000
# eps/alp err = 0.013100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_190_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_190_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.392000
# eps/alp err = 0.012600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_190_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_190_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.393000
# eps/alp err = 0.013000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_190_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_190_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.362000
# eps/alp err = 0.012300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_190_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_190_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.383000
# eps/alp err = 0.012700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_190_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_190_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.402000
# eps/alp err = 0.013100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_190_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_190_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.395000
# eps/alp err = 0.012900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_190_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_190_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.390000
# eps/alp err = 0.012600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_190_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_190_MSD_50.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.387000
# eps/alp err = 0.012500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_190_MSD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_190_MSD_55.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.400000
# eps/alp err = 0.012300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_190_MSD_55.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_190_MSD_60.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.126000
# eps/alp err = 0.006100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_190_MSD_60.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_190_MSD_70.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.004440
# eps/alp err = 0.001080
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_190_MSD_70.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_190_MSD_80.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.005170
# eps/alp err = 0.001160
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_190_MSD_80.csv
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_88_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.394000
# eps/alp err = 0.031100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_88_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_88_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.436000
# eps/alp err = 0.037100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_88_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_88_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.447000
# eps/alp err = 0.040200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_88_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_88_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.421000
# eps/alp err = 0.035700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_88_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_88_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.455000
# eps/alp err = 0.030300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_88_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_88_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.417000
# eps/alp err = 0.028900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_88_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2018_CutFlow_tables/MZD_88_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.447000
# eps/alp err = 0.032200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2018_cutflow_csv/dataframe_MZD_88_MSD_5.csv
#
# File closed successfully

# %%
def save_eps_alph(epsilon_alpha, epsilon_alpha_err):
    pd.dataframe()
    for key in epsilon_alpha.keys():

# %%
eps_alph_dict_2018 = {"dataset": epsilon_alpha_2018.keys(), "epsalp": epsilon_alpha_2018.values(), "err": epsilon_alpha_err_2018.values()}
eps_alph_df_2018 = pd.DataFrame(eps_alph_dict_2018)
eps_alph_df_2018.to_csv("2018_cutflow_csv/eps_alph_2018.csv")

# %%
base_dir  = base_dirs[0]
total_file_list, file_names = get_file_list(base_dir, ".tex")
keys = [key.split(".")[0] for key in file_names] # return keys to be used in dictionary later

keys_dict = {total_file_list[ii].split("/")[1].split(".")[0]: total_file_list[ii] for ii in range(len(total_file_list))}

# %%
keys_dict
# Out:
# {'MZD_110_MSD_10': '2017_CutFlow_tables/MZD_110_MSD_10.tex',
#  'MZD_110_MSD_15': '2017_CutFlow_tables/MZD_110_MSD_15.tex',
#  'MZD_110_MSD_20': '2017_CutFlow_tables/MZD_110_MSD_20.tex',
#  'MZD_110_MSD_25': '2017_CutFlow_tables/MZD_110_MSD_25.tex',
#  'MZD_110_MSD_30': '2017_CutFlow_tables/MZD_110_MSD_30.tex',
#  'MZD_110_MSD_35': '2017_CutFlow_tables/MZD_110_MSD_35.tex',
#  'MZD_110_MSD_40': '2017_CutFlow_tables/MZD_110_MSD_40.tex',
#  'MZD_110_MSD_45': '2017_CutFlow_tables/MZD_110_MSD_45.tex',
#  'MZD_110_MSD_5': '2017_CutFlow_tables/MZD_110_MSD_5.tex',
#  'MZD_110_MSD_50': '2017_CutFlow_tables/MZD_110_MSD_50.tex',
#  'MZD_125_MSD_15': '2017_CutFlow_tables/MZD_125_MSD_15.tex',
#  'MZD_125_MSD_25': '2017_CutFlow_tables/MZD_125_MSD_25.tex',
#  'MZD_125_MSD_30': '2017_CutFlow_tables/MZD_125_MSD_30.tex',
#  'MZD_125_MSD_35': '2017_CutFlow_tables/MZD_125_MSD_35.tex',
#  'MZD_125_MSD_45': '2017_CutFlow_tables/MZD_125_MSD_45.tex',
#  'MZD_125_MSD_5': '2017_CutFlow_tables/MZD_125_MSD_5.tex',
#  'MZD_125_MSD_50': '2017_CutFlow_tables/MZD_125_MSD_50.tex',
#  'MZD_125_MSD_55': '2017_CutFlow_tables/MZD_125_MSD_55.tex',
#  'MZD_130_MSD_10': '2017_CutFlow_tables/MZD_130_MSD_10.tex',
#  'MZD_130_MSD_15': '2017_CutFlow_tables/MZD_130_MSD_15.tex',
#  'MZD_130_MSD_20': '2017_CutFlow_tables/MZD_130_MSD_20.tex',
#  'MZD_130_MSD_25': '2017_CutFlow_tables/MZD_130_MSD_25.tex',
#  'MZD_130_MSD_30': '2017_CutFlow_tables/MZD_130_MSD_30.tex',
#  'MZD_130_MSD_35': '2017_CutFlow_tables/MZD_130_MSD_35.tex',
#  'MZD_130_MSD_40': '2017_CutFlow_tables/MZD_130_MSD_40.tex',
#  'MZD_130_MSD_45': '2017_CutFlow_tables/MZD_130_MSD_45.tex',
#  'MZD_130_MSD_5': '2017_CutFlow_tables/MZD_130_MSD_5.tex',
#  'MZD_130_MSD_50': '2017_CutFlow_tables/MZD_130_MSD_50.tex',
#  'MZD_130_MSD_55': '2017_CutFlow_tables/MZD_130_MSD_55.tex',
#  'MZD_140_MSD_10': '2017_CutFlow_tables/MZD_140_MSD_10.tex',
#  'MZD_140_MSD_15': '2017_CutFlow_tables/MZD_140_MSD_15.tex',
#  'MZD_140_MSD_20': '2017_CutFlow_tables/MZD_140_MSD_20.tex',
#  'MZD_140_MSD_25': '2017_CutFlow_tables/MZD_140_MSD_25.tex',
#  'MZD_140_MSD_30': '2017_CutFlow_tables/MZD_140_MSD_30.tex',
#  'MZD_140_MSD_35': '2017_CutFlow_tables/MZD_140_MSD_35.tex',
#  'MZD_140_MSD_40': '2017_CutFlow_tables/MZD_140_MSD_40.tex',
#  'MZD_140_MSD_45': '2017_CutFlow_tables/MZD_140_MSD_45.tex',
#  'MZD_140_MSD_5': '2017_CutFlow_tables/MZD_140_MSD_5.tex',
#  'MZD_140_MSD_50': '2017_CutFlow_tables/MZD_140_MSD_50.tex',
#  'MZD_140_MSD_55': '2017_CutFlow_tables/MZD_140_MSD_55.tex',
#  'MZD_150_MSD_10': '2017_CutFlow_tables/MZD_150_MSD_10.tex',
#  'MZD_150_MSD_15': '2017_CutFlow_tables/MZD_150_MSD_15.tex',
#  'MZD_150_MSD_20': '2017_CutFlow_tables/MZD_150_MSD_20.tex',
#  'MZD_150_MSD_25': '2017_CutFlow_tables/MZD_150_MSD_25.tex',
#  'MZD_150_MSD_30': '2017_CutFlow_tables/MZD_150_MSD_30.tex',
#  'MZD_150_MSD_35': '2017_CutFlow_tables/MZD_150_MSD_35.tex',
#  'MZD_150_MSD_40': '2017_CutFlow_tables/MZD_150_MSD_40.tex',
#  'MZD_150_MSD_45': '2017_CutFlow_tables/MZD_150_MSD_45.tex',
#  'MZD_150_MSD_5': '2017_CutFlow_tables/MZD_150_MSD_5.tex',
#  'MZD_150_MSD_50': '2017_CutFlow_tables/MZD_150_MSD_50.tex',
#  'MZD_150_MSD_55': '2017_CutFlow_tables/MZD_150_MSD_55.tex',
#  'MZD_160_MSD_10': '2017_CutFlow_tables/MZD_160_MSD_10.tex',
#  'MZD_160_MSD_15': '2017_CutFlow_tables/MZD_160_MSD_15.tex',
#  'MZD_160_MSD_20': '2017_CutFlow_tables/MZD_160_MSD_20.tex',
#  'MZD_160_MSD_25': '2017_CutFlow_tables/MZD_160_MSD_25.tex',
#  'MZD_160_MSD_30': '2017_CutFlow_tables/MZD_160_MSD_30.tex',
#  'MZD_160_MSD_35': '2017_CutFlow_tables/MZD_160_MSD_35.tex',
#  'MZD_160_MSD_40': '2017_CutFlow_tables/MZD_160_MSD_40.tex',
#  'MZD_160_MSD_45': '2017_CutFlow_tables/MZD_160_MSD_45.tex',
#  'MZD_160_MSD_5': '2017_CutFlow_tables/MZD_160_MSD_5.tex',
#  'MZD_160_MSD_50': '2017_CutFlow_tables/MZD_160_MSD_50.tex',
#  'MZD_160_MSD_55': '2017_CutFlow_tables/MZD_160_MSD_55.tex',
#  'MZD_170_MSD_10': '2017_CutFlow_tables/MZD_170_MSD_10.tex',
#  'MZD_170_MSD_15': '2017_CutFlow_tables/MZD_170_MSD_15.tex',
#  'MZD_170_MSD_20': '2017_CutFlow_tables/MZD_170_MSD_20.tex',
#  'MZD_170_MSD_25': '2017_CutFlow_tables/MZD_170_MSD_25.tex',
#  'MZD_170_MSD_30': '2017_CutFlow_tables/MZD_170_MSD_30.tex',
#  'MZD_170_MSD_35': '2017_CutFlow_tables/MZD_170_MSD_35.tex',
#  'MZD_170_MSD_40': '2017_CutFlow_tables/MZD_170_MSD_40.tex',
#  'MZD_170_MSD_45': '2017_CutFlow_tables/MZD_170_MSD_45.tex',
#  'MZD_170_MSD_5': '2017_CutFlow_tables/MZD_170_MSD_5.tex',
#  'MZD_170_MSD_50': '2017_CutFlow_tables/MZD_170_MSD_50.tex',
#  'MZD_170_MSD_55': '2017_CutFlow_tables/MZD_170_MSD_55.tex',
#  'MZD_180_MSD_10': '2017_CutFlow_tables/MZD_180_MSD_10.tex',
#  'MZD_180_MSD_15': '2017_CutFlow_tables/MZD_180_MSD_15.tex',
#  'MZD_180_MSD_20': '2017_CutFlow_tables/MZD_180_MSD_20.tex',
#  'MZD_180_MSD_25': '2017_CutFlow_tables/MZD_180_MSD_25.tex',
#  'MZD_180_MSD_30': '2017_CutFlow_tables/MZD_180_MSD_30.tex',
#  'MZD_180_MSD_35': '2017_CutFlow_tables/MZD_180_MSD_35.tex',
#  'MZD_180_MSD_40': '2017_CutFlow_tables/MZD_180_MSD_40.tex',
#  'MZD_180_MSD_45': '2017_CutFlow_tables/MZD_180_MSD_45.tex',
#  'MZD_180_MSD_5': '2017_CutFlow_tables/MZD_180_MSD_5.tex',
#  'MZD_180_MSD_50': '2017_CutFlow_tables/MZD_180_MSD_50.tex',
#  'MZD_180_MSD_55': '2017_CutFlow_tables/MZD_180_MSD_55.tex',
#  'MZD_190_MSD_10': '2017_CutFlow_tables/MZD_190_MSD_10.tex',
#  'MZD_190_MSD_15': '2017_CutFlow_tables/MZD_190_MSD_15.tex',
#  'MZD_190_MSD_30': '2017_CutFlow_tables/MZD_190_MSD_30.tex',
#  'MZD_190_MSD_35': '2017_CutFlow_tables/MZD_190_MSD_35.tex',
#  'MZD_190_MSD_40': '2017_CutFlow_tables/MZD_190_MSD_40.tex',
#  'MZD_190_MSD_45': '2017_CutFlow_tables/MZD_190_MSD_45.tex',
#  'MZD_190_MSD_5': '2017_CutFlow_tables/MZD_190_MSD_5.tex',
#  'MZD_190_MSD_50': '2017_CutFlow_tables/MZD_190_MSD_50.tex',
#  'MZD_190_MSD_55': '2017_CutFlow_tables/MZD_190_MSD_55.tex',
#  'MZD_200_MSD_10': '2017_CutFlow_tables/MZD_200_MSD_10.tex',
#  'MZD_200_MSD_15': '2017_CutFlow_tables/MZD_200_MSD_15.tex',
#  'MZD_200_MSD_20': '2017_CutFlow_tables/MZD_200_MSD_20.tex',
#  'MZD_200_MSD_25': '2017_CutFlow_tables/MZD_200_MSD_25.tex',
#  'MZD_200_MSD_30': '2017_CutFlow_tables/MZD_200_MSD_30.tex',
#  'MZD_200_MSD_35': '2017_CutFlow_tables/MZD_200_MSD_35.tex',
#  'MZD_200_MSD_40': '2017_CutFlow_tables/MZD_200_MSD_40.tex',
#  'MZD_200_MSD_45': '2017_CutFlow_tables/MZD_200_MSD_45.tex',
#  'MZD_200_MSD_5': '2017_CutFlow_tables/MZD_200_MSD_5.tex',
#  'MZD_200_MSD_50': '2017_CutFlow_tables/MZD_200_MSD_50.tex',
#  'MZD_200_MSD_55': '2017_CutFlow_tables/MZD_200_MSD_55.tex',
#  'MZD_85_MSD_10': '2017_CutFlow_tables/MZD_85_MSD_10.tex',
#  'MZD_85_MSD_15': '2017_CutFlow_tables/MZD_85_MSD_15.tex',
#  'MZD_85_MSD_20': '2017_CutFlow_tables/MZD_85_MSD_20.tex',
#  'MZD_85_MSD_25': '2017_CutFlow_tables/MZD_85_MSD_25.tex',
#  'MZD_85_MSD_30': '2017_CutFlow_tables/MZD_85_MSD_30.tex',
#  'MZD_85_MSD_35': '2017_CutFlow_tables/MZD_85_MSD_35.tex',
#  'MZD_85_MSD_40': '2017_CutFlow_tables/MZD_85_MSD_40.tex',
#  'MZD_85_MSD_5': '2017_CutFlow_tables/MZD_85_MSD_5.tex',
#  'MZD_88_MSD_10': '2017_CutFlow_tables/MZD_88_MSD_10.tex',
#  'MZD_88_MSD_15': '2017_CutFlow_tables/MZD_88_MSD_15.tex',
#  'MZD_88_MSD_20': '2017_CutFlow_tables/MZD_88_MSD_20.tex',
#  'MZD_88_MSD_25': '2017_CutFlow_tables/MZD_88_MSD_25.tex',
#  'MZD_88_MSD_30': '2017_CutFlow_tables/MZD_88_MSD_30.tex',
#  'MZD_88_MSD_35': '2017_CutFlow_tables/MZD_88_MSD_35.tex',
#  'MZD_88_MSD_40': '2017_CutFlow_tables/MZD_88_MSD_40.tex',
#  'MZD_88_MSD_5': '2017_CutFlow_tables/MZD_88_MSD_5.tex',
#  'MZD_91_MSD_10': '2017_CutFlow_tables/MZD_91_MSD_10.tex',
#  'MZD_91_MSD_15': '2017_CutFlow_tables/MZD_91_MSD_15.tex',
#  'MZD_91_MSD_20': '2017_CutFlow_tables/MZD_91_MSD_20.tex',
#  'MZD_91_MSD_25': '2017_CutFlow_tables/MZD_91_MSD_25.tex',
#  'MZD_91_MSD_30': '2017_CutFlow_tables/MZD_91_MSD_30.tex',
#  'MZD_91_MSD_35': '2017_CutFlow_tables/MZD_91_MSD_35.tex',
#  'MZD_91_MSD_40': '2017_CutFlow_tables/MZD_91_MSD_40.tex',
#  'MZD_91_MSD_45': '2017_CutFlow_tables/MZD_91_MSD_45.tex',
#  'MZD_91_MSD_5': '2017_CutFlow_tables/MZD_91_MSD_5.tex',
#  'MZD_95_MSD_10': '2017_CutFlow_tables/MZD_95_MSD_10.tex',
#  'MZD_95_MSD_15': '2017_CutFlow_tables/MZD_95_MSD_15.tex',
#  'MZD_95_MSD_20': '2017_CutFlow_tables/MZD_95_MSD_20.tex',
#  'MZD_95_MSD_25': '2017_CutFlow_tables/MZD_95_MSD_25.tex',
#  'MZD_95_MSD_30': '2017_CutFlow_tables/MZD_95_MSD_30.tex',
#  'MZD_95_MSD_35': '2017_CutFlow_tables/MZD_95_MSD_35.tex',
#  'MZD_95_MSD_40': '2017_CutFlow_tables/MZD_95_MSD_40.tex',
#  'MZD_95_MSD_45': '2017_CutFlow_tables/MZD_95_MSD_45.tex',
#  'MZD_95_MSD_5': '2017_CutFlow_tables/MZD_95_MSD_5.tex'}

# %%
dataDir = "2017_cutflow_csv/"
cutflow_dict_2017, df_dict_2017, epsilon_alpha_2017, epsilon_alpha_err_2017 = process_cutflow(total_file_list, verbose = True)
# Out:
# Opening file 2017_CutFlow_tables/MZD_110_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.001450
# eps/alp err = 0.000841
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_110_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_110_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.393000
# eps/alp err = 0.016300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_110_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_110_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.410000
# eps/alp err = 0.017500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_110_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_110_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.391000
# eps/alp err = 0.016600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_110_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_110_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.395000
# eps/alp err = 0.017000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_110_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_110_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.408000
# eps/alp err = 0.016500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_110_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_110_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.415000
# eps/alp err = 0.015100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_110_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_110_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.414000
# eps/alp err = 0.014300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_110_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_110_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.371000
# eps/alp err = 0.016200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_110_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_110_MSD_50.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.423000
# eps/alp err = 0.014200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_110_MSD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_125_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.400000
# eps/alp err = 0.015300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_125_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_125_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.399000
# eps/alp err = 0.015800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_125_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_125_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.382000
# eps/alp err = 0.015400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_125_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_125_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.393000
# eps/alp err = 0.015600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_125_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_125_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.404000
# eps/alp err = 0.014300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_125_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_125_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.401000
# eps/alp err = 0.015600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_125_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_125_MSD_50.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.410000
# eps/alp err = 0.013500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_125_MSD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_125_MSD_55.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.436000
# eps/alp err = 0.013800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_125_MSD_55.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_130_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.002610
# eps/alp err = 0.000987
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_130_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_130_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.404000
# eps/alp err = 0.015600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_130_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_130_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.415000
# eps/alp err = 0.015500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_130_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_130_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.404000
# eps/alp err = 0.015500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_130_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_130_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.387000
# eps/alp err = 0.015500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_130_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_130_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.393000
# eps/alp err = 0.015300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_130_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_130_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.404000
# eps/alp err = 0.015200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_130_MSD_40.csv
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_130_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.408000
# eps/alp err = 0.014100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_130_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_130_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.399000
# eps/alp err = 0.014900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_130_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_130_MSD_50.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.421000
# eps/alp err = 0.013700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_130_MSD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_130_MSD_55.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.424000
# eps/alp err = 0.013700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_130_MSD_55.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_140_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.002260
# eps/alp err = 0.000924
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_140_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_140_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.380000
# eps/alp err = 0.014600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_140_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_140_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.401000
# eps/alp err = 0.014400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_140_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_140_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.420000
# eps/alp err = 0.014900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_140_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_140_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.394000
# eps/alp err = 0.014700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_140_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_140_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.397000
# eps/alp err = 0.015200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_140_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_140_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.401000
# eps/alp err = 0.013700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_140_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_140_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.401000
# eps/alp err = 0.013700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_140_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_140_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.402000
# eps/alp err = 0.014500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_140_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_140_MSD_50.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.414000
# eps/alp err = 0.013300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_140_MSD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_140_MSD_55.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.423000
# eps/alp err = 0.013300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_140_MSD_55.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_150_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.001070
# eps/alp err = 0.000619
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_150_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_150_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.411000
# eps/alp err = 0.014100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_150_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_150_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.395000
# eps/alp err = 0.014200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_150_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_150_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.392000
# eps/alp err = 0.014100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_150_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_150_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.389000
# eps/alp err = 0.014000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_150_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_150_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.387000
# eps/alp err = 0.014000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_150_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_150_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.385000
# eps/alp err = 0.014200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_150_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_150_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.401000
# eps/alp err = 0.013400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_150_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_150_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.372000
# eps/alp err = 0.012800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_150_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_150_MSD_50.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.372000
# eps/alp err = 0.012200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_150_MSD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_150_MSD_55.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.402000
# eps/alp err = 0.012700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_150_MSD_55.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_160_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.001340
# eps/alp err = 0.000673
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_160_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_160_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.401000
# eps/alp err = 0.013200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_160_MSD_15.csv
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_160_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.396000
# eps/alp err = 0.014000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_160_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_160_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.379000
# eps/alp err = 0.014200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_160_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_160_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.395000
# eps/alp err = 0.013800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_160_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_160_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.401000
# eps/alp err = 0.013900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_160_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_160_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.391000
# eps/alp err = 0.013400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_160_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_160_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.399000
# eps/alp err = 0.013400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_160_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_160_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.392000
# eps/alp err = 0.012900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_160_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_160_MSD_50.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.397000
# eps/alp err = 0.012700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_160_MSD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_160_MSD_55.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.405000
# eps/alp err = 0.012400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_160_MSD_55.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_170_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.000613
# eps/alp err = 0.000433
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_170_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_170_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.386000
# eps/alp err = 0.012700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_170_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_170_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.404000
# eps/alp err = 0.013800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_170_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_170_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.389000
# eps/alp err = 0.013400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_170_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_170_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.378000
# eps/alp err = 0.012900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_170_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_170_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.374000
# eps/alp err = 0.013400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_170_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_170_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.392000
# eps/alp err = 0.013400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_170_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_170_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.400000
# eps/alp err = 0.012800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_170_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_170_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.384000
# eps/alp err = 0.012700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_170_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_170_MSD_50.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.406000
# eps/alp err = 0.013200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_170_MSD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_170_MSD_55.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.404000
# eps/alp err = 0.012400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_170_MSD_55.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_180_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.000307
# eps/alp err = 0.000307
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_180_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_180_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.381000
# eps/alp err = 0.012100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_180_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_180_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.403000
# eps/alp err = 0.013200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_180_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_180_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.374000
# eps/alp err = 0.012600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_180_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_180_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.388000
# eps/alp err = 0.012900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_180_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_180_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.384000
# eps/alp err = 0.012700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_180_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_180_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.388000
# eps/alp err = 0.013100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_180_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_180_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.396000
# eps/alp err = 0.012900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_180_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_180_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.377000
# eps/alp err = 0.011800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_180_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_180_MSD_50.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.387000
# eps/alp err = 0.012200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_180_MSD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_180_MSD_55.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.417000
# eps/alp err = 0.012700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_180_MSD_55.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_190_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.000278
# eps/alp err = 0.000278
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_190_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_190_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.371000
# eps/alp err = 0.012300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_190_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_190_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.391000
# eps/alp err = 0.012900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_190_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_190_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.392000
# eps/alp err = 0.012600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_190_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_190_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.398000
# eps/alp err = 0.012300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_190_MSD_40.csv
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_190_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.401000
# eps/alp err = 0.012800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_190_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_190_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.380000
# eps/alp err = 0.012300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_190_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_190_MSD_50.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.400000
# eps/alp err = 0.012800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_190_MSD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_190_MSD_55.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.404000
# eps/alp err = 0.012400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_190_MSD_55.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_200_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.000270
# eps/alp err = 0.000270
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_200_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_200_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.405000
# eps/alp err = 0.012800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_200_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_200_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.387000
# eps/alp err = 0.012100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_200_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_200_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.376000
# eps/alp err = 0.012300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_200_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_200_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.387000
# eps/alp err = 0.012200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_200_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_200_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.372000
# eps/alp err = 0.013000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_200_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_200_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.373000
# eps/alp err = 0.012600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_200_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_200_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.395000
# eps/alp err = 0.012200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_200_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_200_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.393000
# eps/alp err = 0.011900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_200_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_200_MSD_50.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.382000
# eps/alp err = 0.011900
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_200_MSD_50.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_200_MSD_55.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.397000
# eps/alp err = 0.012000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_200_MSD_55.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_85_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.005390
# eps/alp err = 0.002040
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_85_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_85_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.443000
# eps/alp err = 0.022500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_85_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_85_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.435000
# eps/alp err = 0.021600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_85_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_85_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.431000
# eps/alp err = 0.022800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_85_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_85_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.418000
# eps/alp err = 0.019600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_85_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_85_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.421000
# eps/alp err = 0.016700
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_85_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_85_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.458000
# eps/alp err = 0.015500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_85_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_85_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.402000
# eps/alp err = 0.020000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_85_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_88_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = nan
# eps/alp err = nan
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_88_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_88_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.423000
# eps/alp err = 0.021400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_88_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_88_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.410000
# eps/alp err = 0.021300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_88_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_88_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.418000
# eps/alp err = 0.020800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_88_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_88_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.398000
# eps/alp err = 0.019300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_88_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_88_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.413000
# eps/alp err = 0.016800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_88_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_88_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.439000
# eps/alp err = 0.015400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_88_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_88_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.442000
# eps/alp err = 0.021500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_88_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_91_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.003280
# eps/alp err = 0.001470
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_91_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_91_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.400000
# eps/alp err = 0.020200
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_91_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_91_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.415000
# eps/alp err = 0.020100
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_91_MSD_20.csv
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_91_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.416000
# eps/alp err = 0.019000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_91_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_91_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.425000
# eps/alp err = 0.019300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_91_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_91_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.401000
# eps/alp err = 0.016500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_91_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_91_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.424000
# eps/alp err = 0.015000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_91_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_91_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.475000
# eps/alp err = 0.015400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_91_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_91_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.399000
# eps/alp err = 0.020000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_91_MSD_5.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_95_MSD_10.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.003590
# eps/alp err = 0.001470
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_95_MSD_10.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_95_MSD_15.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.429000
# eps/alp err = 0.019300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_95_MSD_15.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_95_MSD_20.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.395000
# eps/alp err = 0.019600
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_95_MSD_20.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_95_MSD_25.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.397000
# eps/alp err = 0.018300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_95_MSD_25.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_95_MSD_30.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.390000
# eps/alp err = 0.018500
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_95_MSD_30.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_95_MSD_35.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.408000
# eps/alp err = 0.016400
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_95_MSD_35.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_95_MSD_40.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.431000
# eps/alp err = 0.015300
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_95_MSD_40.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_95_MSD_45.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.450000
# eps/alp err = 0.014800
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_95_MSD_45.csv
#
# File closed successfully
#
#
#
#
# Opening file 2017_CutFlow_tables/MZD_95_MSD_5.tex
#
# File opened successfully
#
# Processing file...
# Cutflow table detected, processing...
#
# Epsilon/alpha values:
# *********************
# eps/alp = 0.399000
# eps/alp err = 0.018000
# *********************
#
# Transferring dictionary to pandas dataframe
#
# Saving pandas dataframe to 2017_cutflow_csv/dataframe_MZD_95_MSD_5.csv
#
# File closed successfully

# %%
eps_alph_dict_2017 = {"dataset": epsilon_alpha_2017.keys(), "epsalp": epsilon_alpha_2017.values(), "err": epsilon_alpha_err_2017.values()}
eps_alph_df_2017 = pd.DataFrame(eps_alph_dict_2017)
eps_alph_df_2017.to_csv("2017_cutflow_csv/eps_alph_2017.csv")
